# %%
import pandas as pd

# %%
metadata = pd.read_csv('C:/Users/Big data/Desktop/recom/train.csv', low_memory=False)

# %%
metadata.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# ...

# %%
songs = pd.read_csv('C:/Users/Big data/Desktop/recom/songs.csv', low_memory=False)
members = pd.read_csv('C:/Users/Big data/Desktop/recom/members.csv', low_memory=False)
song_extra_info = pd.read_csv('C:/Users/Big data/Desktop/recom/song_extra_info.csv', low_memory=False)
sample_submission = pd.read_csv('C:/Users/Big data/Desktop/recom/sample_submission.csv', low_memory=False)

# %%
songs.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %%
songs.count()
# Out:
# song_id        2296320
# song_length    2296320
# genre_ids      2202204
# artist_name    2296320
# composer       1224966
# lyricist        351052
# language       2296319
# dtype: int64

# %%
members.head()
# Out:
#                                            msno  city  bd gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0    NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0    NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0    NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0    NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0    NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# 3               9                20150906         20150907
# 4               4                20170126         20170613

# %%
song_extra_info.head()
# Out:
#                                         song_id             name          isrc
# 0  LP7pLJoJFBvyuUwvu+oLzjT+bI+UeBPURCecJsX1jjs=               我們  TWUM71200043
# 1  ClazTFnk6r0Bnuie44bocdNMM3rdlrq0bCGAsGUWcHE=  Let Me Love You  QMZSY1600015
# 2  u2ja/bZE3zhCGxvbbOB3zOoUjx27u40cf5g09UXMoKQ=              原諒我  TWA530887303
# 3  92Fqsy0+p6+RHe2EoLKjHahORHR1Kq1TBJoClW9v+Ts=          Classic  USSM11301446
# 4  0QFmz/+rJy1Q56C1DuYqT9hKKqi5TUqx0sN0IwvoHrw=             愛投羅網  TWA471306001

# %%
song_extra_info.count()
# Out:
# song_id    2295971
# name       2295969
# isrc       2159423
# dtype: int64

# %%
sample_submission.head()
# Out:
#    id  target
# 0   0     0.5
# 1   1     0.5
# 2   2     0.5
# 3   3     0.5
# 4   4     0.5

# %%
metadata = metadata.merge(songs, on='song_id')

# %%
metadata = metadata.merge(song_extra_info, on='song_id')

# %%
song = songs.merge(song_extra_info, on='song_id')
song.head(10)
# Out:
#                                         song_id  song_length        genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640              465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328              444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781              465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554              465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329              726
# 5  kKJ2JNU5h8rphyW21ovC+RZU+yEHPM+3w85J37p7vEQ=       235520  864|857|850|843
# 6  N9vbanw7BSMoUgdfJlgX1aZPE1XZg8OS1wf88AQEcMc=       226220              458
# 7  GsCpr618xfveHYJdo+E5SybrpR906tsjLMeKyrCNw8s=       276793              465
# 8  oTi7oINPX+rxoGp+3O6llSltQTl80jDqHoULfRoLcG4=       228623              465
# 9  btcG03OHY3GNKWccPP0auvtSbhxog/kllIIOx5grE/k=       232629         352|1995
#
#          artist_name                                           composer  \
# ...

# %%
song.count()
# Out:
# song_id        2295422
# song_length    2295422
# genre_ids      2201349
# artist_name    2295422
# composer       1224484
# lyricist        350899
# language       2295421
# name           2295420
# isrc           2158892
# dtype: int64

# %%
metadata
# Out:
#                                                  msno  \
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 7        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 8        uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 9        uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 10       uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 11       uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 12       TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 13       3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# 14       TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 15       3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# ...

# %%
metadata.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  e5Ezre9HPuPos+CXQXtmo32E/hHIZTMmo6jG3yRf6UA=
# 2  pouJqjNRmZOnRNzzMWWkamTKkIGHyvhl/jo4HgbncnM=
# 3  sSexP400TJOZRhx3JB+0s9cqrCnqrlV51B9njoKR1II=
# 4  hKdGiUKHVqKkXGHLrc+EzdSW6q0ERAJ2Cs7/L1N0Ae4=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=        my library
# 2  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=          discover
# 3  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=          discover
# 4  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=          discover
#
#      source_screen_name      source_type  target  song_length genre_ids  \
# 0               Explore  online-playlist       1       206471       359
# 1   Local playlist more   local-playlist       1       206471       359
# ...

# %%
import numpy as np

# %%
a = metadata[['song_id', 'genre_ids', 'artist_name', 'composer','lyricist', 'name']]

# %%
a
# Out:
#                                               song_id genre_ids  \
# 0        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 1        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 2        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 3        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 4        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 5        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 6        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 7        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 8        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 9        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 10       BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 11       BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 12       BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 13       BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# ...

# %%
metadata.count()
# Out:
# msno                  7375849
# song_id               7375849
# source_system_tab     7351006
# source_screen_name    6961148
# source_type           7354314
# target                7375849
# song_length           7375849
# genre_ids             7257512
# artist_name           7375849
# composer              5700724
# lyricist              4197876
# language              7375813
# name                  7375847
# isrc                  6799455
# dtype: int64

# %%
a = a.drop_duplicates(subset=['song_id'], keep=False)
a
# Out:
#                                               song_id genre_ids  \
# 215      bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=      1259
# 220      2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=      1019
# 37439    WHEVGSHBtJBVy+HjH84qRtj0KcNtYd+2pUO4xHMAJXk=      2022
# 37440    TLUDFNRpLCG/DmqLiXBc4Udypwucj4XmKtotIUO6nXM=       465
# 41840    P6dllZw/ZnO7qcufxOKHAXGwlCvkmm4djJT/82d3ihA=       465
# 43331    MM+huiuccu4p5mNVhWxWgJreIsRWuEmvbvpCu0q79XM=       465
# 259580   WTQ1doDa8xAetUIXq+G/3AmF8/GPtJfRtbjaaj0vGqQ=       465
# 268337   u70RByc176rGRQLAmXdf7WNM0vU2RrkkYnY7z1wOPyA=   921|465
# 269073   uSBqdKWlDHhk/U85eSKfWr014iYbeIEv3DIu/RcYuqw=   940|388
# 269074   /tRJOn8mjgWkOnGmG7h43o4hClfmi5hZ9F2r5ZL8F/k=   921|465
# 532374   pfmY16EfQekUrFsCQKS0ptDcOoGpRcNKNy0aZwHLuks=      2122
# 722549   d7LtyALDMDuIKf18CkEwIKSq2s3n9is80oVbOXY/1m0=      2022
# 863105   T+gG6igGOilMSihjbN3Pm3J1eG1mx2lUwxfrJlcMfhA=       465
# 873773   cy+Bv/P1BHhyRl/Q7lNv8GmdzUF+9zfPLoK+Ywhqs4w=       465
# ...

# %%
metadata.count()
# Out:
# msno                  7375849
# song_id               7375849
# source_system_tab     7351006
# source_screen_name    6961148
# source_type           7354314
# target                7375849
# song_length           7375849
# genre_ids             7257512
# artist_name           7375849
# composer              5700724
# lyricist              4197876
# language              7375813
# name                  7375847
# isrc                  6799455
# dtype: int64

# %%
a.count()
# Out:
# song_id        166679
# genre_ids      162087
# artist_name    166679
# composer        91583
# lyricist        32495
# name           166679
# dtype: int64

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
         if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
         else:
            return ''
features = ['genre_ids', 'artist_name', 'composer','lyricist']

for feature in features:
    b[feature] = b[feature].apply(clean_data)
    
def create_soup(x):
    return ' '.join(x['genre_ids']) + ' ' + ' '.join(x['artist_name']) + ' ' + x['composer'] + ' ' + ' '.join(x['lyricist'])
b['soup'] = b.apply(create_soup, axis=1)
# Out:
# C:\Users\Big data\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\Big data\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
metadata
# Out:
#                                               song_id genre_ids  \
# 0        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 1        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 2        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 3        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 4        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 5        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 6        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 7        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 8        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 9        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 10       BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 11       BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 12       BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# 13       BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=       359
# ...

# %%
song.head(10)
# Out:
#                                         song_id  song_length        genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640              465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328              444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781              465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554              465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329              726
# 5  kKJ2JNU5h8rphyW21ovC+RZU+yEHPM+3w85J37p7vEQ=       235520  864|857|850|843
# 6  N9vbanw7BSMoUgdfJlgX1aZPE1XZg8OS1wf88AQEcMc=       226220              458
# 7  GsCpr618xfveHYJdo+E5SybrpR906tsjLMeKyrCNw8s=       276793              465
# 8  oTi7oINPX+rxoGp+3O6llSltQTl80jDqHoULfRoLcG4=       228623              465
# 9  btcG03OHY3GNKWccPP0auvtSbhxog/kllIIOx5grE/k=       232629         352|1995
#
#          artist_name                                           composer  \
# ...

# %%
b = song[['song_id', 'genre_ids', 'artist_name', 'composer','lyricist', 'name']]

# %%
features = ['genre_ids', 'artist_name', 'composer','lyricist']

for feature in features:
    b[feature] = b[feature].apply(clean_data)
# Out:
# C:\Users\Big data\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
b.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b52e47057087> in <module>()
# ----> 1 b.head(10)
#
# NameError: name 'b' is not defined

# %%
def create_soup(x):
    return ' '.join(x['genre_ids']) + ' ' + ' '.join(x['artist_name']) + ' ' + x['composer'] + ' ' + ' '.join(x['lyricist'])
b['soup'] = b.apply(create_soup, axis=1)

# %%
b.count()
# Out:
# song_id        2295422
# genre_ids      2295422
# artist_name    2295422
# composer       2295422
# lyricist       2295422
# name           2295420
# dtype: int64

# %%
b['song_id'].nunique()
# Out:
# 2295422

# %%
b['soup'] = b.apply(create_soup, axis=1)
# Out:
# C:\Users\Big data\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x = b.head(60000)

# %%
from sklearn.feature_extraction.text import CountVectorizer
countx = CountVectorizer(stop_words='english')
countx_matrix = countx.fit_transform(x['soup'])
cosine_simx = cosine_similarity(countx_matrix, countx_matrix)

# %%
def get_recommendations(name, cosine_simx=cosine_simx):
    # Get the index of the movie that matches the title
    idx = indices[name]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_simx[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return x['name'].iloc[movie_indices]

# %%
indices = pd.Series(x.index, index=x['name']).drop_duplicates()

# %%
x
# Out:
#                                             song_id        genre_ids  \
# 0      CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=              465
# 1      o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=              444
# 2      DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=              465
# 3      dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=              465
# 4      W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=              726
# 5      kKJ2JNU5h8rphyW21ovC+RZU+yEHPM+3w85J37p7vEQ=  864|857|850|843
# 6      N9vbanw7BSMoUgdfJlgX1aZPE1XZg8OS1wf88AQEcMc=              458
# 7      GsCpr618xfveHYJdo+E5SybrpR906tsjLMeKyrCNw8s=              465
# 8      oTi7oINPX+rxoGp+3O6llSltQTl80jDqHoULfRoLcG4=              465
# 9      btcG03OHY3GNKWccPP0auvtSbhxog/kllIIOx5grE/k=         352|1995
# 10     HulM/OaHgD5kUyjNQjDUf8VZdsy7h4EJUIff79Cifwo=             2157
# 11     wypPzqFNdUJAqyBVxmFGaK4z7krUNWr5YqA0q0wi9eE=              465
# 12     fAZLdfQaLG76a6Ei4alt1eSjBM9rshQkiQEC6+n+y08=              726
# ...

# %%
get_recommendations('Bae Bae')
# Out:
# 26693                               LOSER
# 2972     THE LEADERS (FEAT.TEDDY|2NE1之CL)
# 14737                              LIFTED
# 16958                                壁虎漫步
# 23566                   声をきかせて　-Club Mix-
# 33455                      BANG BANG BANG
# 52344                              Zutter
# 54282                              CRAYON
# 57547                             BAE BAE
# 59122                              CRAYON
# Name: name, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(b['soup'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-100-f6352040fe89> in <module>()
# ----> 1 cosine_sim = cosine_similarity(count_matrix, count_matrix)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#     923         Y_normalized = normalize(Y, copy=True)
#     924
# --> 925     K = safe_sparse_dot(X_normalized, Y_normalized.T, dense_output=dense_output)
#     926
#     927     return K
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     133     """
#     134     if issparse(a) or issparse(b):
# --> 135         ret = a * b
#     136         if dense_output and hasattr(ret, "toarray"):
#     137             ret = ret.toarray()
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\base.py in __mul__(self, other)
# ...

# %%
a['song_id'].nunique()
# Out:
# 166679

# %%
a
# Out:
#                                               song_id genre_ids  \
# 215      bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=      1259
# 220      2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=      1019
# 37439    WHEVGSHBtJBVy+HjH84qRtj0KcNtYd+2pUO4xHMAJXk=      2022
# 37440    TLUDFNRpLCG/DmqLiXBc4Udypwucj4XmKtotIUO6nXM=       465
# 41840    P6dllZw/ZnO7qcufxOKHAXGwlCvkmm4djJT/82d3ihA=       465
# 43331    MM+huiuccu4p5mNVhWxWgJreIsRWuEmvbvpCu0q79XM=       465
# 259580   WTQ1doDa8xAetUIXq+G/3AmF8/GPtJfRtbjaaj0vGqQ=       465
# 268337   u70RByc176rGRQLAmXdf7WNM0vU2RrkkYnY7z1wOPyA=   921|465
# 269073   uSBqdKWlDHhk/U85eSKfWr014iYbeIEv3DIu/RcYuqw=   940|388
# 269074   /tRJOn8mjgWkOnGmG7h43o4hClfmi5hZ9F2r5ZL8F/k=   921|465
# 532374   pfmY16EfQekUrFsCQKS0ptDcOoGpRcNKNy0aZwHLuks=      2122
# 722549   d7LtyALDMDuIKf18CkEwIKSq2s3n9is80oVbOXY/1m0=      2022
# 863105   T+gG6igGOilMSihjbN3Pm3J1eG1mx2lUwxfrJlcMfhA=       465
# 873773   cy+Bv/P1BHhyRl/Q7lNv8GmdzUF+9zfPLoK+Ywhqs4w=       465
# ...

# %%
b
# Out:
#                                               song_id        genre_ids  \
# 0        CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=              465
# 1        o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=              444
# 2        DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=              465
# 3        dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=              465
# 4        W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=              726
# 5        kKJ2JNU5h8rphyW21ovC+RZU+yEHPM+3w85J37p7vEQ=  864|857|850|843
# 6        N9vbanw7BSMoUgdfJlgX1aZPE1XZg8OS1wf88AQEcMc=              458
# 7        GsCpr618xfveHYJdo+E5SybrpR906tsjLMeKyrCNw8s=              465
# 8        oTi7oINPX+rxoGp+3O6llSltQTl80jDqHoULfRoLcG4=              465
# 9        btcG03OHY3GNKWccPP0auvtSbhxog/kllIIOx5grE/k=         352|1995
# 10       HulM/OaHgD5kUyjNQjDUf8VZdsy7h4EJUIff79Cifwo=             2157
# 11       wypPzqFNdUJAqyBVxmFGaK4z7krUNWr5YqA0q0wi9eE=              465
# ...

# %%
def create_soup1(x):
    return  ' '.join(x['artist_name']) + ' ' + x['composer'] + ' ' + ' '.join(x['lyricist'])

# %%
a['soup'] = a.apply(create_soup1, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-611a12b6b2a1> in <module>()
# ----> 1 a['soup'] = a.apply(create_soup1, axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# ...
