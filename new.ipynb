# %%
from sklearn import cross_validation, grid_search, metrics, ensemble
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl# Load Python libraries
from sklearn import cross_validation, grid_search, metrics, ensemble
# Out:
# C:\Users\Big data\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\Big data\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
df = pd.read_csv('C:/Users/Big data/downloads/rank_data1.csv')

# %%
dfo = df[['1st','2nd','3rd','4th','5th']] 
dfo
# Out:
#         1st        2nd        3rd          4th          5th
# 0       465        458       1259          359          474
# 1       465        458        444         1259         1011
# 2       465        458   465|1259     465|2022          921
# 3       458        465        921         1609          NaN
# 4       465        458        921         1609    1616|1609
# 5       451  1616|1609       2022          458          465
# 6      2022        465        437         1955          458
# 7       465       2022   465|1259          NaN          NaN
# 8       465        458        921         1011         1259
# 9       465        458        451      465|798          786
# 10      465        458       1609         1259          921
# 11      465        921        458         1609          359
# 12      458        465        921         1609          786
# 13      465        458   465|1259         1609     1609|465
# 14      458        465        NaN          NaN          NaN
# ...

# %%
k = []
for i in range(len(dfo)):
    k.append(dfo.loc[i,['1st','2nd','3rd','4th','5th']])

# %%
k
# Out:
# [1st     465
#  2nd     458
#  3rd    1259
#  4th     359
#  5th     474
#  Name: 0, dtype: object, 1st     465
#  2nd     458
#  3rd     444
#  4th    1259
#  5th    1011
#  Name: 1, dtype: object, 1st         465
#  2nd         458
#  3rd    465|1259
#  4th    465|2022
#  5th         921
#  Name: 2, dtype: object, 1st     458
#  2nd     465
#  3rd     921
#  4th    1609
#  5th     NaN
#  Name: 3, dtype: object, 1st          465
#  2nd          458
#  3rd          921
#  4th         1609
#  5th    1616|1609
#  Name: 4, dtype: object, 1st          451
#  2nd    1616|1609
#  3rd         2022
#  4th          458
#  5th          465
#  Name: 5, dtype: object, 1st    2022
#  2nd     465
#  3rd     437
#  4th    1955
#  5th     458
#  Name: 6, dtype: object, 1st         465
#  2nd        2022
#  3rd    465|1259
#  4th         NaN
#  5th         NaN
#  Name: 7, dtype: object, 1st     465
#  2nd     458
#  3rd     921
#  4th    1011
#  5th    1259
#  Name: 8, dtype: object, 1st        465
# ...

# %%
score
# Out:
# ['465',
#  '458',
#  '1259',
#  '359',
#  '474',
#  '465',
#  '458',
#  '444',
#  '1259',
#  '1011',
#  '465',
#  '458',
#  '465|1259',
#  '465|2022',
#  '921',
#  '458',
#  '465',
#  '921',
#  '1609',
#  nan,
#  '465',
#  '458',
#  '921',
#  '1609',
#  '1616|1609',
#  '451',
#  '1616|1609',
#  '2022',
#  '458',
#  '465',
#  '2022',
#  '465',
#  '437',
#  '1955',
#  '458',
#  '465',
#  '2022',
#  '465|1259',
#  nan,
#  nan,
#  '465',
#  '458',
#  '921',
#  '1011',
#  '1259',
#  '465',
#  '458',
#  '451',
#  '465|798',
#  '786',
#  '465',
#  '458',
#  '1609',
#  '1259',
#  '921',
#  '465',
#  '921',
#  '458',
#  '1609',
#  '359',
#  '458',
#  '465',
#  '921',
#  '1609',
#  '786',
#  '465',
#  '458',
#  '465|1259',
#  '1609',
#  '1609|465',
#  '458',
#  '465',
#  nan,
#  nan,
#  nan,
#  '465',
#  '458',
#  '1259',
#  '1609',
#  '2022',
#  '458',
#  '465',
#  '921',
#  '1609',
#  '451',
#  '458',
#  '465',
#  '451',
#  '921',
#  '139',
#  '465',
#  '1609',
#  '359',
#  '139',
#  '437',
# ...

# %%
len(score)
# Out:
# 153775

# %%
w = list(df['msno'])

# %%
len(w)
# Out:
# 30755

# %%
r = []
for i in w:
    r.append(i*5)
r
# Out:
# ['++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk=++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk=++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk=++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk=++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk=',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU=++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU=++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU=++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU=++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU=',
# ...

# %%
b = []
for i in r:
    b.extend(i.split('='))

# %%
b
# Out:
# ['++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU',
# ...

# %%
for i in b:
    b.remove('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-b1508d56cfa0> in <module>()
#       1 for i in b:
# ----> 2     b.remove('')
#
# ValueError: list.remove(x): x not in list

# %%
b
# Out:
# ['++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU',
#  '++xWL5Pbi2CpG4uUugigQahauM0J/sBIRloTNPBybIU',
# ...

# %%
len(b)
# Out:
# 153775

# %%
df_rank = pd.DataFrame(data=b)

# %%
df_rank['genre_id'] = score

# %%
df_rank
# Out:
#                                                   0   genre_id
# 0       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        465
# 1       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        458
# 2       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU       1259
# 3       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        359
# 4       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        474
# 5       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg        465
# 6       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg        458
# 7       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg        444
# 8       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg       1259
# 9       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg       1011
# 10      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk        465
# 11      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk        458
# 12      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk   465|1259
# 13      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk   465|2022
# ...

# %%
data = {"id":b,'genre_id':really_score}
df = pd.DataFrame(data)
df
# Out:
#                                                  id   genre_id
# 0       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        465
# 1       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        458
# 2       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU       1259
# 3       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        359
# 4       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        474
# 5       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg        465
# 6       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg        458
# 7       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg        444
# 8       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg       1259
# 9       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg       1011
# 10      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk        465
# 11      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk        458
# 12      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk   465|1259
# 13      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk   465|2022
# ...

# %%
g = [5,4,3,2,1]
rank = g * 30755

# %%
len(rank)
# Out:
# 153775

# %%
data = {"id":b,'genre_id':score,'rank':rank}
df = pd.DataFrame(data)
df
# Out:
#                                                  id   genre_id  rank
# 0       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        465     5
# 1       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        458     4
# 2       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU       1259     3
# 3       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        359     2
# 4       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU        474     1
# 5       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg        465     5
# 6       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg        458     4
# 7       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg        444     3
# 8       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg       1259     2
# 9       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg       1011     1
# 10      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk        465     5
# 11      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk        458     4
# 12      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk   465|1259     3
# ...

# %%
df.to_csv('rank_data2.csv',index = False)

# %%
df['id'] = df['id'] + '='

# %%
df
# Out:
#                                                   id   genre_id  rank
# 0       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=        465     5
# 1       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=        458     4
# 2       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=       1259     3
# 3       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=        359     2
# 4       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=        474     1
# 5       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=        465     5
# 6       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=        458     4
# 7       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=        444     3
# 8       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=       1259     2
# 9       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=       1011     1
# 10      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk=        465     5
# 11      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk=        458     4
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
dfo
# Out:
#         1st        2nd        3rd          4th          5th
# 0       465        458       1259          359          474
# 1       465        458        444         1259         1011
# 2       465        458   465|1259     465|2022          921
# 3       458        465        921         1609          NaN
# 4       465        458        921         1609    1616|1609
# 5       451  1616|1609       2022          458          465
# 6      2022        465        437         1955          458
# 7       465       2022   465|1259          NaN          NaN
# 8       465        458        921         1011         1259
# 9       465        458        451      465|798          786
# 10      465        458       1609         1259          921
# 11      465        921        458         1609          359
# 12      458        465        921         1609          786
# 13      465        458   465|1259         1609     1609|465
# 14      458        465        NaN          NaN          NaN
# ...

# %%
score
# Out:
# ['465',
#  '458',
#  '1259',
#  '359',
#  '474',
#  '465',
#  '458',
#  '444',
#  '1259',
#  '1011',
#  '465',
#  '458',
#  '465|1259',
#  '465|2022',
#  '921',
#  '458',
#  '465',
#  '921',
#  '1609',
#  nan,
#  '465',
#  '458',
#  '921',
#  '1609',
#  '1616|1609',
#  '451',
#  '1616|1609',
#  '2022',
#  '458',
#  '465',
#  '2022',
#  '465',
#  '437',
#  '1955',
#  '458',
#  '465',
#  '2022',
#  '465|1259',
#  nan,
#  nan,
#  '465',
#  '458',
#  '921',
#  '1011',
#  '1259',
#  '465',
#  '458',
#  '451',
#  '465|798',
#  '786',
#  '465',
#  '458',
#  '1609',
#  '1259',
#  '921',
#  '465',
#  '921',
#  '458',
#  '1609',
#  '359',
#  '458',
#  '465',
#  '921',
#  '1609',
#  '786',
#  '465',
#  '458',
#  '465|1259',
#  '1609',
#  '1609|465',
#  '458',
#  '465',
#  nan,
#  nan,
#  nan,
#  '465',
#  '458',
#  '1259',
#  '1609',
#  '2022',
#  '458',
#  '465',
#  '921',
#  '1609',
#  '451',
#  '458',
#  '465',
#  '451',
#  '921',
#  '139',
#  '465',
#  '1609',
#  '359',
#  '139',
#  '437',
# ...

# %%
set(score)
# Out:
# {'1007',
#  '1011',
#  '1019',
#  '1026',
#  '1033',
#  '1040',
#  '1047',
#  '1082',
#  '109',
#  '1096',
#  '109|1259',
#  '109|139',
#  '109|359',
#  '1103',
#  '1138',
#  '1145',
#  '1145|1110',
#  '1152',
#  '1152|2022',
#  '1152|242|947',
#  '1152|359',
#  '1152|423',
#  '1152|465',
#  '1152|465|1180',
#  '1152|726',
#  '1152|786',
#  '1152|786|947',
#  '1152|829',
#  '1152|873',
#  '1152|873|947',
#  '1152|921',
#  '1152|940',
#  '1152|947',
#  '1162',
#  '1169',
#  '118',
#  '1180',
#  '1180|465',
#  '118|1259',
#  '1208',
#  '1259',
#  '1259|139|125|109',
#  '1259|359',
#  '125|95',
#  '1266',
#  '1280|2093',
#  '1287',
#  '139',
#  '139|1259',
#  '139|1259|125|109',
#  '139|125|109',
#  '139|125|109|2022',
#  '139|444|109',
#  '1568',
#  '1572',
#  '1572|275',
#  '1598',
#  '1605',
#  '1609',
#  '1609|1259',
#  '1609|2022',
#  '1609|2058',
#  '1609|2086|374',
#  '1609|2107',
#  '1609|2122|958',
#  '1609|282',
#  '1609|359',
#  '1609|458',
#  '1609|465',
#  '1609|509',
# ...

# %%
score
# Out:
# ['465',
#  '458',
#  '1259',
#  '359',
#  '474',
#  '465',
#  '458',
#  '444',
#  '1259',
#  '1011',
#  '465',
#  '458',
#  '465|1259',
#  '465|2022',
#  '921',
#  '458',
#  '465',
#  '921',
#  '1609',
#  nan,
#  '465',
#  '458',
#  '921',
#  '1609',
#  '1616|1609',
#  '451',
#  '1616|1609',
#  '2022',
#  '458',
#  '465',
#  '2022',
#  '465',
#  '437',
#  '1955',
#  '458',
#  '465',
#  '2022',
#  '465|1259',
#  nan,
#  nan,
#  '465',
#  '458',
#  '921',
#  '1011',
#  '1259',
#  '465',
#  '458',
#  '451',
#  '465|798',
#  '786',
#  '465',
#  '458',
#  '1609',
#  '1259',
#  '921',
#  '465',
#  '921',
#  '458',
#  '1609',
#  '359',
#  '458',
#  '465',
#  '921',
#  '1609',
#  '786',
#  '465',
#  '458',
#  '465|1259',
#  '1609',
#  '1609|465',
#  '458',
#  '465',
#  nan,
#  nan,
#  nan,
#  '465',
#  '458',
#  '1259',
#  '1609',
#  '2022',
#  '458',
#  '465',
#  '921',
#  '1609',
#  '451',
#  '458',
#  '465',
#  '451',
#  '921',
#  '139',
#  '465',
#  '1609',
#  '359',
#  '139',
#  '437',
# ...

# %%
(score[12])
# Out:
# '465|1259'

# %%
k=[]
for i in score:
    if '|' in i:
        i.split('|')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-c80546bf8e3d> in <module>()
#       1 k=[]
#       2 for i in score:
# ----> 3     if '|' in i:
#       4         i.split('|')
#       5
#
# TypeError: argument of type 'float' is not iterable

# %%
a = list(set(score))
a
# Out:
# [nan,
#  '921|947',
#  '1208',
#  '2086|374',
#  '1995',
#  '465|2022',
#  '388|873',
#  '465|139',
#  '465|798',
#  '1633',
#  '488',
#  '545',
#  '139|1259',
#  '458|139|109',
#  '1152|423',
#  '458|1287',
#  '2130',
#  '2032',
#  '2215',
#  '940',
#  '465|726',
#  '1011',
#  '2130|2122|958',
#  '516|465',
#  '1609|509',
#  '786|2122',
#  '388|2189|367',
#  '880',
#  '2052',
#  '1633|310',
#  '786|947|2086|374',
#  '921|458',
#  '2157',
#  '352|1995',
#  '465|1011',
#  '465|829',
#  '1977',
#  '1259|359',
#  '531',
#  '242|947',
#  '1103',
#  '880|873|947',
#  '118|1259',
#  '1152|921',
#  '2022|1955',
#  '1616|2072',
#  '1609|2086|374',
#  '726|958',
#  '1287',
#  '465|458',
#  '880|458',
#  '109',
#  '786|947',
#  '1609|2122|958',
#  '1609|947|2022',
#  '829|458',
#  '437|2022',
#  '1572|275',
#  '900',
#  '1609|465',
#  '139|125|109',
#  '381|2086',
#  '444|829',
#  '965',
#  '1598',
#  '2022',
#  '1152|726',
#  '850',
#  '979',
#  '2022|2122',
#  '873|465',
#  '465|2122',
# ...

# %%
type(df['rank'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#                                                   id   genre_id  rank
# 0       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=        465     5
# 1       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=        458     4
# 2       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=       1259     3
# 3       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=        359     2
# 4       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=        474     1
# 5       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=        465     5
# 6       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=        458     4
# 7       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=        444     3
# 8       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=       1259     2
# 9       ++AH7m/EQ4iKe6wSlfO/xXAJx50p+fCeTyF90GoE9Pg=       1011     1
# 10      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk=        465     5
# 11      ++e+jsxuQ8UEnmW40od9Rq3rW7+wAum4wooXyZTKJpk=        458     4
# ...

# %%
q = df.groupby('genre_id').mean()
q
# Out:
#                               rank
# genre_id
# 1007                      2.500000
# 1011                      2.085055
# 1019                      1.500000
# 1026                      3.000000
# 1033                      1.000000
# 1040                      2.000000
# 1047                      2.333333
# 1082                      2.161290
# 109                       1.615385
# 1096                      2.000000
# 109|1259                  3.000000
# 109|139                   2.375000
# 109|359                   1.000000
# 1103                      3.333333
# 1138                      2.153846
# 1145                      2.000000
# 1145|1110                 2.000000
# 1152                      2.360927
# 1152|2022                 1.714286
# 1152|242|947              1.000000
# 1152|359                  3.000000
# 1152|423                  2.000000
# 1152|465                  2.000000
# 1152|465|1180             5.000000
# 1152|726                  1.750000
# ...

# %%
len(q.sort_values(by=['rank'], ascending=False))
# Out:
# 266
