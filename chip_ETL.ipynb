# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_excel('C:/Users/Big data/Downloads/CPT_0006_bd.xls')

# %%
df
# Out:
#                          6                                         Unnamed: 1  \
# 0                      832                                                NaN
# 1    Information Section\n                                                NaN
# 2                 ********                                                NaN
# 3                 ********                                                NaN
# 4                 ********                                                NaN
# 5                      NaN                                     CpTest Format:
# 6                      NaN                                               S/N:
# 7                        0                                              Date:
# 8                      NaN                                         File Name:
# 9                      NaN                                  Card electrical -
# 10                     NaN                                                NaN
# ...

# %%
df.drop(6, axis=1, inplace = True)

# %%
df
# Out:
#                                             Unnamed: 1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                       CpTest Format:
# 6                                                 S/N:
# 7                                                Date:
# 8                                           File Name:
# 9                                    Card electrical -
# 10                                                 NaN
# 11                                                 NaN
# 12                                     Card physical -
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# ...

# %%
df['Unnamed: 1'][:50]
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                        CpTest Format:
# 6                                                  S/N:
# 7                                                 Date:
# 8                                            File Name:
# 9                                     Card electrical -
# 10                                                  NaN
# 11                                                  NaN
# 12                                      Card physical -
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
test = df.drop(range(38))

# %%
print(range(38))
# Out:
# range(0, 38)

# %%
test
# Out:
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5   Unnamed: 6  \
# 38          Ch         EC         Tr        Pad       Leak         CRes
# 39         141   VSUB_LNA        GND       1101    4.01209      1.41666
# 40         438    VDD_ANA      12212       1103     311.08      1.96471
# 41         141    VSS_ANA        GND       1105    4.01209      1.41666
# 42         564       VDD4      12203       1108    299.875      2.11625
# 43         566     XTAL_I      12205       1110    7.30823  9.13234e+08
# 44         167     XTAL_O      12102       1111   0.159493          >1G
# 45         141       VSS4        GND       1112    4.01209      1.41666
# 46         141       VSS1        GND       1113    4.01209      1.41666
# 47         563       VDD1      12201       1114    918.797      2.36904
# 48         141       VSS1        GND       1116    4.01209      1.41666
# 49         363      VBCKP    304_P14       1118   0.257585          >1G
# ...

# %%
# test.drop(['Unnamed: 21','Unnamed: 22','Unnamed: 23'], axis=1, inplace = True)
test.head()
# Out:
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 38         Ch         EC         Tr        Pad       Leak       CRes
# 39        141   VSUB_LNA        GND       1101    4.01209    1.41666
# 40        438    VDD_ANA      12212       1103     311.08    1.96471
# 41        141    VSS_ANA        GND       1105    4.01209    1.41666
# 42        564       VDD4      12203       1108    299.875    2.11625
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 38      VXErr      VYErr       Plan       Force         OVL       Scrub
# 39     6.1948    -0.6116   -67.1875         NaN           P     13.1366
# 40    -3.2898     1.3844         nf         NaN           P      7.8051
# 41    -0.3636     -3.623   -66.9548         NaN           P     12.1154
# 42     5.3779    -2.3969   -61.9872         NaN           P     15.6414
#
#    Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# ...

# %%
test.columns = list(test.loc[38])

# %%
test.head()
# Out:
#      Ch        EC     Tr   Pad     Leak     CRes   VXErr   VYErr     Plan  \
# 38   Ch        EC     Tr   Pad     Leak     CRes   VXErr   VYErr     Plan
# 39  141  VSUB_LNA    GND  1101  4.01209  1.41666  6.1948 -0.6116 -67.1875
# 40  438   VDD_ANA  12212  1103   311.08  1.96471 -3.2898  1.3844       nf
# 41  141   VSS_ANA    GND  1105  4.01209  1.41666 -0.3636  -3.623 -66.9548
# 42  564      VDD4  12203  1108  299.875  2.11625  5.3779 -2.3969 -61.9872
#
#     Force  OVL    Scrub   TScrub   AScrub   ScrAng      Dia     Caps  \
# 38  Force  OVL    Scrub   TScrub   AScrub   ScrAng      Dia     Caps
# 39    NaN    P  13.1366  71.1875  3409.31 -31.4002  58.0509  145.338
# 40    NaN    P   7.8051  63.7045  2890.47 -24.9002  55.8994      NaN
# 41    NaN    P  12.1154  68.0089  3130.82  19.1002  55.8935  145.338
# 42    NaN    P  15.6414  76.8106  3895.47  17.9002  61.1691      NaN
#
#                    Remarks   XRef   YRef
# 38                 Remarks   XRef   YRef
# ...

# %%
test.drop(38, inplace = True)

# %%
test.head()
# Out:
#      Ch        EC     Tr   Pad     Leak         CRes   VXErr   VYErr     Plan  \
# 39  141  VSUB_LNA    GND  1101  4.01209      1.41666  6.1948 -0.6116 -67.1875
# 40  438   VDD_ANA  12212  1103   311.08      1.96471 -3.2898  1.3844       nf
# 41  141   VSS_ANA    GND  1105  4.01209      1.41666 -0.3636  -3.623 -66.9548
# 42  564      VDD4  12203  1108  299.875      2.11625  5.3779 -2.3969 -61.9872
# 43  566    XTAL_I  12205  1110  7.30823  9.13234e+08  1.2828  4.8981       nf
#
#    Force OVL    Scrub   TScrub   AScrub   ScrAng      Dia        Caps  \
# 39   NaN   P  13.1366  71.1875  3409.31 -31.4002  58.0509     145.338
# 40   NaN   P   7.8051  63.7045  2890.47 -24.9002  55.8994         NaN
# 41   NaN   P  12.1154  68.0089  3130.82  19.1002  55.8935     145.338
# 42   NaN   P  15.6414  76.8106  3895.47  17.9002  61.1691         NaN
# 43   NaN   P   6.0884  63.7638  2963.74   3.8002  57.6754  0.00138951
#
#                    Remarks   XRef   YRef
# ...

# %%
test
# Out:
#        Ch        EC       Tr    Pad       Leak         CRes   VXErr   VYErr  \
# 39    141  VSUB_LNA      GND   1101    4.01209      1.41666  6.1948 -0.6116
# 40    438   VDD_ANA    12212   1103     311.08      1.96471 -3.2898  1.3844
# 41    141   VSS_ANA      GND   1105    4.01209      1.41666 -0.3636  -3.623
# 42    564      VDD4    12203   1108    299.875      2.11625  5.3779 -2.3969
# 43    566    XTAL_I    12205   1110    7.30823  9.13234e+08  1.2828  4.8981
# 44    167    XTAL_O    12102   1111   0.159493          >1G  3.4897  4.8143
# 45    141      VSS4      GND   1112    4.01209      1.41666 -0.4129  1.1107
# 46    141      VSS1      GND   1113    4.01209      1.41666 -5.2157  2.1456
# 47    563      VDD1    12201   1114    918.797      2.36904  0.3729  -5.265
# 48    141      VSS1      GND   1116    4.01209      1.41666  1.9622  3.8068
# 49    363     VBCKP  304_P14   1118   0.257585          >1G -1.1293  3.1747
# ...

# %%
def CRes(x):
    if type(x) == str:
        x = round(1 + random.random(), 4)
        return x
    
    else:
        x = round((x),4)
        return x

# %%
for i in range(len(test['CRes'])):
    print(test['CRes'][i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-7a8ae60c1f1f> in <module>()
#       1 for i in range(len(test['CRes'])):
# ----> 2     print(test['CRes'][i])
#       3
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2558         try:
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
#    2562             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# ...

# %%
test['CRes'] = test['CRes'].apply(CRes)

# %%
test
# Out:
#        Ch        EC       Tr    Pad       Leak          CRes   VXErr   VYErr  \
# 39    141  VSUB_LNA      GND   1101    4.01209  1.416700e+00  6.1948 -0.6116
# 40    438   VDD_ANA    12212   1103     311.08  1.964700e+00 -3.2898  1.3844
# 41    141   VSS_ANA      GND   1105    4.01209  1.416700e+00 -0.3636  -3.623
# 42    564      VDD4    12203   1108    299.875  2.116300e+00  5.3779 -2.3969
# 43    566    XTAL_I    12205   1110    7.30823  9.132342e+08  1.2828  4.8981
# 44    167    XTAL_O    12102   1111   0.159493  1.784600e+00  3.4897  4.8143
# 45    141      VSS4      GND   1112    4.01209  1.416700e+00 -0.4129  1.1107
# 46    141      VSS1      GND   1113    4.01209  1.416700e+00 -5.2157  2.1456
# 47    563      VDD1    12201   1114    918.797  2.369000e+00  0.3729  -5.265
# 48    141      VSS1      GND   1116    4.01209  1.416700e+00  1.9622  3.8068
# 49    363     VBCKP  304_P14   1118   0.257585  1.188400e+00 -1.1293  3.1747
# ...

# %%
test.to_excel('test.xlsx',index = False)
