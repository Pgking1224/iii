# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
df = pd.read_csv('C:/Users/Big data/Downloads/hou_100.csv')

# %%
df
# Out:
#            年月                          地址               類型  \
# 0     107年03月         中正區仁愛路一段31~60號 檢視位置      電梯大樓/住宅 含車位
# 1     107年03月         中正區寧波東街9巷1~30號 檢視位置            華廈/住宅
# 2     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 3     107年03月          中正區廈門街91~120號 檢視位置     電梯大樓/純車位 含車位
# 4     107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置      無電梯公寓/住宅/住宅
# 5     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 6     107年03月      中正區汀州路三段160巷1~30號 檢視位置            華廈/住宅
# 7     107年03月         中正區汀州路三段31~60號 檢視位置       電梯大樓/住宅/套房
# 8     107年03月      中正區新生南路一段151~180號 檢視位置  電梯大樓/辦公商業大樓 含車位
# 9     107年03月         中正區金山南路一段1~30號 檢視位置      電梯大樓/住宅 含車位
# 10    107年03月         中正區牯嶺街95巷1~30號 檢視位置          電梯大樓/住宅
# 11    107年03月       中正區汀州路二段12巷1~30號 檢視位置            華廈/住宅
# 12    107年03月        中正區和平西路二段31~60號 檢視位置         華廈/套房/住宅
# 13    107年02月         中正區臨沂街19巷1~30號 檢視位置         無電梯公寓/住宅
# 14    107年02月         中正區濟南路二段31~60號 檢視位置  無電梯公寓/住宅/辦公商業大樓
# ...

# %%
a = df[~df['地址'].isnull()] #把地址null質篩選掉後的df
a
# Out:
#            年月                          地址               類型  \
# 0     107年03月         中正區仁愛路一段31~60號 檢視位置      電梯大樓/住宅 含車位
# 1     107年03月         中正區寧波東街9巷1~30號 檢視位置            華廈/住宅
# 2     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 3     107年03月          中正區廈門街91~120號 檢視位置     電梯大樓/純車位 含車位
# 4     107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置      無電梯公寓/住宅/住宅
# 5     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 6     107年03月      中正區汀州路三段160巷1~30號 檢視位置            華廈/住宅
# 7     107年03月         中正區汀州路三段31~60號 檢視位置       電梯大樓/住宅/套房
# 8     107年03月      中正區新生南路一段151~180號 檢視位置  電梯大樓/辦公商業大樓 含車位
# 9     107年03月         中正區金山南路一段1~30號 檢視位置      電梯大樓/住宅 含車位
# 10    107年03月         中正區牯嶺街95巷1~30號 檢視位置          電梯大樓/住宅
# 11    107年03月       中正區汀州路二段12巷1~30號 檢視位置            華廈/住宅
# 12    107年03月        中正區和平西路二段31~60號 檢視位置         華廈/套房/住宅
# 13    107年02月         中正區臨沂街19巷1~30號 檢視位置         無電梯公寓/住宅
# 14    107年02月         中正區濟南路二段31~60號 檢視位置  無電梯公寓/住宅/辦公商業大樓
# ...

# %%
b = df.filter(df[df['地址'].isnull()])

# %%
b
# Out:
#            年月                          地址               類型  \
# 0     107年03月         中正區仁愛路一段31~60號 檢視位置      電梯大樓/住宅 含車位
# 1     107年03月         中正區寧波東街9巷1~30號 檢視位置            華廈/住宅
# 2     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 3     107年03月          中正區廈門街91~120號 檢視位置     電梯大樓/純車位 含車位
# 4     107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置      無電梯公寓/住宅/住宅
# 5     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 6     107年03月      中正區汀州路三段160巷1~30號 檢視位置            華廈/住宅
# 7     107年03月         中正區汀州路三段31~60號 檢視位置       電梯大樓/住宅/套房
# 8     107年03月      中正區新生南路一段151~180號 檢視位置  電梯大樓/辦公商業大樓 含車位
# 9     107年03月         中正區金山南路一段1~30號 檢視位置      電梯大樓/住宅 含車位
# 10    107年03月         中正區牯嶺街95巷1~30號 檢視位置          電梯大樓/住宅
# 11    107年03月       中正區汀州路二段12巷1~30號 檢視位置            華廈/住宅
# 12    107年03月        中正區和平西路二段31~60號 檢視位置         華廈/套房/住宅
# 13    107年02月         中正區臨沂街19巷1~30號 檢視位置         無電梯公寓/住宅
# 14    107年02月         中正區濟南路二段31~60號 檢視位置  無電梯公寓/住宅/辦公商業大樓
# ...

# %%
b
# Out:
#            年月                          地址               類型  \
# 0     107年03月         中正區仁愛路一段31~60號 檢視位置      電梯大樓/住宅 含車位
# 1     107年03月         中正區寧波東街9巷1~30號 檢視位置            華廈/住宅
# 2     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 3     107年03月          中正區廈門街91~120號 檢視位置     電梯大樓/純車位 含車位
# 4     107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置      無電梯公寓/住宅/住宅
# 5     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 6     107年03月      中正區汀州路三段160巷1~30號 檢視位置            華廈/住宅
# 7     107年03月         中正區汀州路三段31~60號 檢視位置       電梯大樓/住宅/套房
# 8     107年03月      中正區新生南路一段151~180號 檢視位置  電梯大樓/辦公商業大樓 含車位
# 9     107年03月         中正區金山南路一段1~30號 檢視位置      電梯大樓/住宅 含車位
# 10    107年03月         中正區牯嶺街95巷1~30號 檢視位置          電梯大樓/住宅
# 11    107年03月       中正區汀州路二段12巷1~30號 檢視位置            華廈/住宅
# 12    107年03月        中正區和平西路二段31~60號 檢視位置         華廈/套房/住宅
# 13    107年02月         中正區臨沂街19巷1~30號 檢視位置         無電梯公寓/住宅
# 14    107年02月         中正區濟南路二段31~60號 檢視位置  無電梯公寓/住宅/辦公商業大樓
# ...

# %%
a.count()
# Out:
# 年月      1903
# 地址      1903
# 類型      1903
# 總價      1903
# 每坪單價    1903
# 建坪      1903
# 地坪      1903
# 屋齡      1903
# 樓層      1903
# 格局      1903
# 特殊      1903
# 0          0
# 1          0
# dtype: int64

# %%
a['地址']=a['地址'].apply(lambda x: x.split('檢視位置')[0])
# Out:
# C:\Users\Big data\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a
# Out:
#            年月                          地址               類型  \
# 0     107年03月         中正區仁愛路一段31~60號 檢視位置      電梯大樓/住宅 含車位
# 1     107年03月         中正區寧波東街9巷1~30號 檢視位置            華廈/住宅
# 2     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 3     107年03月          中正區廈門街91~120號 檢視位置     電梯大樓/純車位 含車位
# 4     107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置      無電梯公寓/住宅/住宅
# 5     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 6     107年03月      中正區汀州路三段160巷1~30號 檢視位置            華廈/住宅
# 7     107年03月         中正區汀州路三段31~60號 檢視位置       電梯大樓/住宅/套房
# 8     107年03月      中正區新生南路一段151~180號 檢視位置  電梯大樓/辦公商業大樓 含車位
# 9     107年03月         中正區金山南路一段1~30號 檢視位置      電梯大樓/住宅 含車位
# 10    107年03月         中正區牯嶺街95巷1~30號 檢視位置          電梯大樓/住宅
# 11    107年03月       中正區汀州路二段12巷1~30號 檢視位置            華廈/住宅
# 12    107年03月        中正區和平西路二段31~60號 檢視位置         華廈/套房/住宅
# 13    107年02月         中正區臨沂街19巷1~30號 檢視位置         無電梯公寓/住宅
# 14    107年02月         中正區濟南路二段31~60號 檢視位置  無電梯公寓/住宅/辦公商業大樓
# ...

# %%
c = a[~a['類型'].isnull()]
c
# Out:
#            年月                          地址               類型  \
# 0     107年03月         中正區仁愛路一段31~60號 檢視位置      電梯大樓/住宅 含車位
# 1     107年03月         中正區寧波東街9巷1~30號 檢視位置            華廈/住宅
# 2     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 3     107年03月          中正區廈門街91~120號 檢視位置     電梯大樓/純車位 含車位
# 4     107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置      無電梯公寓/住宅/住宅
# 5     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 6     107年03月      中正區汀州路三段160巷1~30號 檢視位置            華廈/住宅
# 7     107年03月         中正區汀州路三段31~60號 檢視位置       電梯大樓/住宅/套房
# 8     107年03月      中正區新生南路一段151~180號 檢視位置  電梯大樓/辦公商業大樓 含車位
# 9     107年03月         中正區金山南路一段1~30號 檢視位置      電梯大樓/住宅 含車位
# 10    107年03月         中正區牯嶺街95巷1~30號 檢視位置          電梯大樓/住宅
# 11    107年03月       中正區汀州路二段12巷1~30號 檢視位置            華廈/住宅
# 12    107年03月        中正區和平西路二段31~60號 檢視位置         華廈/套房/住宅
# 13    107年02月         中正區臨沂街19巷1~30號 檢視位置         無電梯公寓/住宅
# 14    107年02月         中正區濟南路二段31~60號 檢視位置  無電梯公寓/住宅/辦公商業大樓
# ...

# %%
c['類型'].apply(lambda x: x.split('/')[0])
# Out:
# 0             電梯大樓
# 1               華廈
# 2               華廈
# 3             電梯大樓
# 4            無電梯公寓
# 5               華廈
# 6               華廈
# 7             電梯大樓
# 8             電梯大樓
# 9             電梯大樓
# 10            電梯大樓
# 11              華廈
# 12              華廈
# 13           無電梯公寓
# 14           無電梯公寓
# 15              華廈
# 16           無電梯公寓
# 17             純土地
# 18          華廈 含車位
# 19             純土地
# 20              華廈
# 21        住宅大樓 含車位
# 22            電梯大樓
# 23            電梯大樓
# 24              華廈
# 25              華廈
# 26           無電梯公寓
# 27            電梯大樓
# 28              公寓
# 29              套房
#            ...
# 1883            公寓
# 1884      住宅大樓 含車位
# 1885           純車位
# 1886            公寓
# 1887            公寓
# 1888            公寓
# 1889        華廈 含車位
# 1890            套房
# 1891           純車位
# 1892        辦公商業大樓
# 1893        套房 含車位
# 1894           透天厝
# 1895           純車位
# 1896           純車位
# 1897      住宅大樓 含車位
# 1898            公寓
# ...

# %%
d = e.assign(housetype=e['類型'].apply(lambda x: x.split('/')[0]))
d
# Out:
#            年月                      地址               類型                  總價  \
# 0     107年03月         中正區仁愛路一段31~60號       電梯大樓/住宅 含車位     4388萬  (含車位--萬)
# 1     107年03月         中正區寧波東街9巷1~30號             華廈/住宅               1150萬
# 2     107年03月         中正區臨沂街29巷1~30號         華廈/住宅 含車位    3177萬  (含車位250萬)
# 3     107年03月          中正區廈門街91~120號      電梯大樓/純車位 含車位     132萬  (含車位132萬)
# 4     107年03月  中正區新生南路一段140巷10弄1~30號       無電梯公寓/住宅/住宅                880萬
# 5     107年03月         中正區臨沂街29巷1~30號         華廈/住宅 含車位    3758萬  (含車位250萬)
# 6     107年03月      中正區汀州路三段160巷1~30號             華廈/住宅                940萬
# 7     107年03月         中正區汀州路三段31~60號        電梯大樓/住宅/套房                980萬
# 8     107年03月      中正區新生南路一段151~180號   電梯大樓/辦公商業大樓 含車位    9250萬  (含車位600萬)
# 9     107年03月         中正區金山南路一段1~30號       電梯大樓/住宅 含車位    3880萬  (含車位400萬)
# 10    107年03月         中正區牯嶺街95巷1~30號           電梯大樓/住宅               2150萬
# ...

# %%
e = c[c['類型'] != '純土地']

f = e[e['類型'] != '純車位']

# %%
f
# Out:
#            年月                          地址               類型  \
# 0     107年03月         中正區仁愛路一段31~60號 檢視位置      電梯大樓/住宅 含車位
# 1     107年03月         中正區寧波東街9巷1~30號 檢視位置            華廈/住宅
# 2     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 3     107年03月          中正區廈門街91~120號 檢視位置     電梯大樓/純車位 含車位
# 4     107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置      無電梯公寓/住宅/住宅
# 5     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 6     107年03月      中正區汀州路三段160巷1~30號 檢視位置            華廈/住宅
# 7     107年03月         中正區汀州路三段31~60號 檢視位置       電梯大樓/住宅/套房
# 8     107年03月      中正區新生南路一段151~180號 檢視位置  電梯大樓/辦公商業大樓 含車位
# 9     107年03月         中正區金山南路一段1~30號 檢視位置      電梯大樓/住宅 含車位
# 10    107年03月         中正區牯嶺街95巷1~30號 檢視位置          電梯大樓/住宅
# 11    107年03月       中正區汀州路二段12巷1~30號 檢視位置            華廈/住宅
# 12    107年03月        中正區和平西路二段31~60號 檢視位置         華廈/套房/住宅
# 13    107年02月         中正區臨沂街19巷1~30號 檢視位置         無電梯公寓/住宅
# 14    107年02月         中正區濟南路二段31~60號 檢視位置  無電梯公寓/住宅/辦公商業大樓
# ...

# %%
g = f.assign(housetype=f['類型'].apply(lambda x: x.split('/')[0]))
g
# Out:
#            年月                          地址               類型  \
# 0     107年03月         中正區仁愛路一段31~60號 檢視位置      電梯大樓/住宅 含車位
# 1     107年03月         中正區寧波東街9巷1~30號 檢視位置            華廈/住宅
# 2     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 3     107年03月          中正區廈門街91~120號 檢視位置     電梯大樓/純車位 含車位
# 4     107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置      無電梯公寓/住宅/住宅
# 5     107年03月         中正區臨沂街29巷1~30號 檢視位置        華廈/住宅 含車位
# 6     107年03月      中正區汀州路三段160巷1~30號 檢視位置            華廈/住宅
# 7     107年03月         中正區汀州路三段31~60號 檢視位置       電梯大樓/住宅/套房
# 8     107年03月      中正區新生南路一段151~180號 檢視位置  電梯大樓/辦公商業大樓 含車位
# 9     107年03月         中正區金山南路一段1~30號 檢視位置      電梯大樓/住宅 含車位
# 10    107年03月         中正區牯嶺街95巷1~30號 檢視位置          電梯大樓/住宅
# 11    107年03月       中正區汀州路二段12巷1~30號 檢視位置            華廈/住宅
# 12    107年03月        中正區和平西路二段31~60號 檢視位置         華廈/套房/住宅
# 13    107年02月         中正區臨沂街19巷1~30號 檢視位置         無電梯公寓/住宅
# 14    107年02月         中正區濟南路二段31~60號 檢視位置  無電梯公寓/住宅/辦公商業大樓
# ...

# %%
g['類型']
# Out:
# 0           電梯大樓/住宅 含車位
# 1                 華廈/住宅
# 2             華廈/住宅 含車位
# 3          電梯大樓/純車位 含車位
# 4           無電梯公寓/住宅/住宅
# 5             華廈/住宅 含車位
# 6                 華廈/住宅
# 7            電梯大樓/住宅/套房
# 8       電梯大樓/辦公商業大樓 含車位
# 9           電梯大樓/住宅 含車位
# 10              電梯大樓/住宅
# 11                華廈/住宅
# 12             華廈/套房/住宅
# 13             無電梯公寓/住宅
# 14      無電梯公寓/住宅/辦公商業大樓
# 15                華廈/住宅
# 16             無電梯公寓/住宅
# 18               華廈 含車位
# 20                   華廈
# 21             住宅大樓 含車位
# 22          電梯大樓/住宅 含車位
# 23              電梯大樓/住宅
# 24            華廈/住宅 含車位
# 25         華廈/住宅/辦公商業大樓
# 26          無電梯公寓/住宅/住宅
# 27              電梯大樓/住宅
# 28                   公寓
# 29                   套房
# 30                 住宅大樓
# 31                   公寓
#              ...
# 1870             辦公商業大樓
# 1871                 華廈
# 1872                透天厝
# 1873                透天厝
# 1874                 公寓
# 1875           住宅大樓 含車位
# 1876           住宅大樓 含車位
# ...

# %%
g.head()
# Out:
#         年月                          地址            類型                總價  \
# 0  107年03月         中正區仁愛路一段31~60號 檢視位置   電梯大樓/住宅 含車位   4388萬  (含車位--萬)
# 1  107年03月         中正區寧波東街9巷1~30號 檢視位置         華廈/住宅             1150萬
# 2  107年03月         中正區臨沂街29巷1~30號 檢視位置     華廈/住宅 含車位  3177萬  (含車位250萬)
# 3  107年03月          中正區廈門街91~120號 檢視位置  電梯大樓/純車位 含車位   132萬  (含車位132萬)
# 4  107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置   無電梯公寓/住宅/住宅              880萬
#
#                 每坪單價                  建坪     地坪     屋齡       樓層  \
# 0              75.8萬    57.88坪  (含車位--坪)  7.79坪  19.5年  2 /共16層
# 1              92.5萬              12.43坪  2.16坪  28.2年   4 /共7層
# 2  91.3萬  (扣除車位價及車坪)  41.58坪  (含車位9.53坪)  9.34坪  25.2年   4 /共6層
# 3     0萬  (扣除車位價及車坪)   4.75坪  (含車位4.75坪)  0.39坪   9.3年  1 /共12層
# 4              48.1萬               18.3坪  6.13坪  51.1年   2 /共4層
#
#                                     格局 特殊   0    1 housetype
# 0     3房/2廳/2衛/0室 近捷運 善導寺站 》 近捷運 東門站 》  無 NaN  NaN      電梯大樓
# ...

# %%
g['car'] = g['類型'].apply(lambda x: '含車位' if '含車位' in x else '無車位')

# %%
g.head()
# Out:
#         年月                          地址            類型                總價  \
# 0  107年03月         中正區仁愛路一段31~60號 檢視位置   電梯大樓/住宅 含車位   4388萬  (含車位--萬)
# 1  107年03月         中正區寧波東街9巷1~30號 檢視位置         華廈/住宅             1150萬
# 2  107年03月         中正區臨沂街29巷1~30號 檢視位置     華廈/住宅 含車位  3177萬  (含車位250萬)
# 3  107年03月          中正區廈門街91~120號 檢視位置  電梯大樓/純車位 含車位   132萬  (含車位132萬)
# 4  107年03月  中正區新生南路一段140巷10弄1~30號 檢視位置   無電梯公寓/住宅/住宅              880萬
#
#                 每坪單價                  建坪     地坪     屋齡       樓層  \
# 0              75.8萬    57.88坪  (含車位--坪)  7.79坪  19.5年  2 /共16層
# 1              92.5萬              12.43坪  2.16坪  28.2年   4 /共7層
# 2  91.3萬  (扣除車位價及車坪)  41.58坪  (含車位9.53坪)  9.34坪  25.2年   4 /共6層
# 3     0萬  (扣除車位價及車坪)   4.75坪  (含車位4.75坪)  0.39坪   9.3年  1 /共12層
# 4              48.1萬               18.3坪  6.13坪  51.1年   2 /共4層
#
#                                     格局 特殊   0    1 housetype  car
# 0     3房/2廳/2衛/0室 近捷運 善導寺站 》 近捷運 東門站 》  無 NaN  NaN      電梯大樓  含車位
# ...

# %%
g['類型']
# Out:
# 0           電梯大樓/住宅 含車位
# 1                 華廈/住宅
# 2             華廈/住宅 含車位
# 3          電梯大樓/純車位 含車位
# 4           無電梯公寓/住宅/住宅
# 5             華廈/住宅 含車位
# 6                 華廈/住宅
# 7            電梯大樓/住宅/套房
# 8       電梯大樓/辦公商業大樓 含車位
# 9           電梯大樓/住宅 含車位
# 10              電梯大樓/住宅
# 11                華廈/住宅
# 12             華廈/套房/住宅
# 13             無電梯公寓/住宅
# 14      無電梯公寓/住宅/辦公商業大樓
# 15                華廈/住宅
# 16             無電梯公寓/住宅
# 18               華廈 含車位
# 20                   華廈
# 21             住宅大樓 含車位
# 22          電梯大樓/住宅 含車位
# 23              電梯大樓/住宅
# 24            華廈/住宅 含車位
# 25         華廈/住宅/辦公商業大樓
# 26          無電梯公寓/住宅/住宅
# 27              電梯大樓/住宅
# 28                   公寓
# 29                   套房
# 30                 住宅大樓
# 31                   公寓
#              ...
# 1870             辦公商業大樓
# 1871                 華廈
# 1872                透天厝
# 1873                透天厝
# 1874                 公寓
# 1875           住宅大樓 含車位
# 1876           住宅大樓 含車位
# ...

# %%
g['地址']=g['地址'].apply(lambda x: x.split('~')[0])

# %%
g['地址']
# Out:
# 0              中正區仁愛路一段31
# 1              中正區寧波東街9巷1
# 2              中正區臨沂街29巷1
# 3                中正區廈門街91
# 4       中正區新生南路一段140巷10弄1
# 5              中正區臨沂街29巷1
# 6           中正區汀州路三段160巷1
# 7              中正區汀州路三段31
# 8            中正區新生南路一段151
# 9              中正區金山南路一段1
# 10             中正區牯嶺街95巷1
# 11           中正區汀州路二段12巷1
# 12            中正區和平西路二段31
# 13             中正區臨沂街19巷1
# 14             中正區濟南路二段31
# 15           中正區延平南路230巷1
# 16             中正區臨沂街57巷1
# 18           中正區仁愛路二段15巷1
# 20                中正區襄陽路1
# 21              中正區?門街121
# 22           中正區中華路一段95巷1
# 23            中正區南昌路一段121
# 24            中正區和平西路二段91
# 25           中正區中華路二段39巷1
# 26             中正區臨沂街44巷1
# 27             中正區仁愛路二段61
# 28               中正區牯嶺街61
# 29            中正區和平西路一段31
# 30            中正區廈門街113巷1
# 31           中正區?門街123巷31
#               ...
# 1870           中正區重慶南路一段1
# 1871          中正區中華路二段301
# 1872            中正區武昌街一段1
# 1873            中正區武昌街一段1
# 1874             中正區詔安街61
# ...

# %%
g['地址'] = g['地址']+'號'
g['地址']
# Out:
# 0              中正區仁愛路一段31號
# 1              中正區寧波東街9巷1號
# 2              中正區臨沂街29巷1號
# 3                中正區廈門街91號
# 4       中正區新生南路一段140巷10弄1號
# 5              中正區臨沂街29巷1號
# 6           中正區汀州路三段160巷1號
# 7              中正區汀州路三段31號
# 8            中正區新生南路一段151號
# 9              中正區金山南路一段1號
# 10             中正區牯嶺街95巷1號
# 11           中正區汀州路二段12巷1號
# 12            中正區和平西路二段31號
# 13             中正區臨沂街19巷1號
# 14             中正區濟南路二段31號
# 15           中正區延平南路230巷1號
# 16             中正區臨沂街57巷1號
# 18           中正區仁愛路二段15巷1號
# 20                中正區襄陽路1號
# 21              中正區?門街121號
# 22           中正區中華路一段95巷1號
# 23            中正區南昌路一段121號
# 24            中正區和平西路二段91號
# 25           中正區中華路二段39巷1號
# 26             中正區臨沂街44巷1號
# 27             中正區仁愛路二段61號
# 28               中正區牯嶺街61號
# 29            中正區和平西路一段31號
# 30            中正區廈門街113巷1號
# 31           中正區?門街123巷31號
#                ...
# 1870           中正區重慶南路一段1號
# 1871          中正區中華路二段301號
# 1872            中正區武昌街一段1號
# ...

# %%
g
# Out:
#            年月                  地址               類型                  總價  \
# 0     107年03月         中正區仁愛路一段31號      電梯大樓/住宅 含車位     4388萬  (含車位--萬)
# 1     107年03月         中正區寧波東街9巷1號            華廈/住宅               1150萬
# 2     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位    3177萬  (含車位250萬)
# 3     107年03月           中正區廈門街91號     電梯大樓/純車位 含車位     132萬  (含車位132萬)
# 4     107年03月  中正區新生南路一段140巷10弄1號      無電梯公寓/住宅/住宅                880萬
# 5     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位    3758萬  (含車位250萬)
# 6     107年03月      中正區汀州路三段160巷1號            華廈/住宅                940萬
# 7     107年03月         中正區汀州路三段31號       電梯大樓/住宅/套房                980萬
# 8     107年03月       中正區新生南路一段151號  電梯大樓/辦公商業大樓 含車位    9250萬  (含車位600萬)
# 9     107年03月         中正區金山南路一段1號      電梯大樓/住宅 含車位    3880萬  (含車位400萬)
# 10    107年03月         中正區牯嶺街95巷1號          電梯大樓/住宅               2150萬
# 11    107年03月       中正區汀州路二段12巷1號            華廈/住宅               1100萬
# ...

# %%
a = g.assign(district=g['地址'].apply(lambda x: x.split('區')[0]))

a['district'] = a['district'] + '區'
a.head()
# Out:
#         年月                  地址            類型                總價  \
# 0  107年03月         中正區仁愛路一段31號   電梯大樓/住宅 含車位   4388萬  (含車位--萬)
# 1  107年03月         中正區寧波東街9巷1號         華廈/住宅             1150萬
# 2  107年03月         中正區臨沂街29巷1號     華廈/住宅 含車位  3177萬  (含車位250萬)
# 3  107年03月           中正區廈門街91號  電梯大樓/純車位 含車位   132萬  (含車位132萬)
# 4  107年03月  中正區新生南路一段140巷10弄1號   無電梯公寓/住宅/住宅              880萬
#
#                 每坪單價                  建坪     地坪     屋齡       樓層  \
# 0              75.8萬    57.88坪  (含車位--坪)  7.79坪  19.5年  2 /共16層
# 1              92.5萬              12.43坪  2.16坪  28.2年   4 /共7層
# 2  91.3萬  (扣除車位價及車坪)  41.58坪  (含車位9.53坪)  9.34坪  25.2年   4 /共6層
# 3     0萬  (扣除車位價及車坪)   4.75坪  (含車位4.75坪)  0.39坪   9.3年  1 /共12層
# 4              48.1萬               18.3坪  6.13坪  51.1年   2 /共4層
#
#                                     格局 特殊   0    1 housetype  car district
# 0     3房/2廳/2衛/0室 近捷運 善導寺站 》 近捷運 東門站 》  無 NaN  NaN      電梯大樓  含車位      中正區
# ...

# %%
b = a.drop(columns = ['0'])
c = b.drop(columns = ['1'])

c.head()
# Out:
#         年月                  地址            類型                總價  \
# 0  107年03月         中正區仁愛路一段31號   電梯大樓/住宅 含車位   4388萬  (含車位--萬)
# 1  107年03月         中正區寧波東街9巷1號         華廈/住宅             1150萬
# 2  107年03月         中正區臨沂街29巷1號     華廈/住宅 含車位  3177萬  (含車位250萬)
# 3  107年03月           中正區廈門街91號  電梯大樓/純車位 含車位   132萬  (含車位132萬)
# 4  107年03月  中正區新生南路一段140巷10弄1號   無電梯公寓/住宅/住宅              880萬
#
#                 每坪單價                  建坪     地坪     屋齡       樓層  \
# 0              75.8萬    57.88坪  (含車位--坪)  7.79坪  19.5年  2 /共16層
# 1              92.5萬              12.43坪  2.16坪  28.2年   4 /共7層
# 2  91.3萬  (扣除車位價及車坪)  41.58坪  (含車位9.53坪)  9.34坪  25.2年   4 /共6層
# 3     0萬  (扣除車位價及車坪)   4.75坪  (含車位4.75坪)  0.39坪   9.3年  1 /共12層
# 4              48.1萬               18.3坪  6.13坪  51.1年   2 /共4層
#
#                                     格局 特殊 housetype  car district
# 0     3房/2廳/2衛/0室 近捷運 善導寺站 》 近捷運 東門站 》  無      電梯大樓  含車位      中正區
# 1             1房/1廳/1衛/0室 近捷運 中正紀念堂站 》  無        華廈  無車位      中正區
# ...

# %%
c.head()
# Out:
#         年月                  地址            類型                總價  \
# 0  107年03月         中正區仁愛路一段31號   電梯大樓/住宅 含車位   4388萬  (含車位--萬)
# 1  107年03月         中正區寧波東街9巷1號         華廈/住宅             1150萬
# 2  107年03月         中正區臨沂街29巷1號     華廈/住宅 含車位  3177萬  (含車位250萬)
# 3  107年03月           中正區廈門街91號  電梯大樓/純車位 含車位   132萬  (含車位132萬)
# 4  107年03月  中正區新生南路一段140巷10弄1號   無電梯公寓/住宅/住宅              880萬
#
#                 每坪單價                  建坪     地坪     屋齡       樓層  \
# 0              75.8萬    57.88坪  (含車位--坪)  7.79坪  19.5年  2 /共16層
# 1              92.5萬              12.43坪  2.16坪  28.2年   4 /共7層
# 2  91.3萬  (扣除車位價及車坪)  41.58坪  (含車位9.53坪)  9.34坪  25.2年   4 /共6層
# 3     0萬  (扣除車位價及車坪)   4.75坪  (含車位4.75坪)  0.39坪   9.3年  1 /共12層
# 4              48.1萬               18.3坪  6.13坪  51.1年   2 /共4層
#
#                                     格局 特殊 housetype  car district
# 0     3房/2廳/2衛/0室 近捷運 善導寺站 》 近捷運 東門站 》  無      電梯大樓  含車位      中正區
# 1             1房/1廳/1衛/0室 近捷運 中正紀念堂站 》  無        華廈  無車位      中正區
# ...

# %%
c['每坪單價']=c['每坪單價'].apply(lambda x: x.split('萬')[0])
c['每坪單價']
# Out:
# 0          75.8
# 1          92.5
# 2          91.3
# 3             0
# 4          48.1
# 5          85.6
# 6          89.3
# 7          73.1
# 8          80.8
# 9          85.5
# 10           73
# 11         61.4
# 12         62.4
# 13         80.8
# 14           80
# 15         54.6
# 16         68.7
# 18           82
# 20         59.2
# 21         60.7
# 22         87.5
# 23         86.7
# 24         68.2
# 25         58.9
# 26         68.8
# 27         90.7
# 28         56.1
# 29           95
# 30         53.4
# 31         50.1
#          ...
# 1870       60.6
# 1871       64.5
# 1872    * 101.3
# 1873    * 101.3
# 1874       40.4
# 1875      116.8
# 1876     * 43.2
# 1877       81.6
# 1878     * 37.1
# 1879       69.8
# 1880     * 73.7
# 1882       82.9
# 1883         59
# 1884       93.5
# 1886       50.6
# 1887       74.9
# 1888       76.6
# 1889       65.7
# 1890       88.4
# 1892         29
# 1893       59.4
# 1894       98.2
# 1897       69.9
# 1898     * 34.2
# ...

# %%
c['每坪單價'] = c['每坪單價'].apply(lambda x: x.split(' ')[1] if '*' in x else x)
c['每坪單價']
# Out:
# 0        75.8
# 1        92.5
# 2        91.3
# 3           0
# 4        48.1
# 5        85.6
# 6        89.3
# 7        73.1
# 8        80.8
# 9        85.5
# 10         73
# 11       61.4
# 12       62.4
# 13       80.8
# 14         80
# 15       54.6
# 16       68.7
# 18         82
# 20       59.2
# 21       60.7
# 22       87.5
# 23       86.7
# 24       68.2
# 25       58.9
# 26       68.8
# 27       90.7
# 28       56.1
# 29         95
# 30       53.4
# 31       50.1
#         ...
# 1870     60.6
# 1871     64.5
# 1872    101.3
# 1873    101.3
# 1874     40.4
# 1875    116.8
# 1876     43.2
# 1877     81.6
# 1878     37.1
# 1879     69.8
# 1880     73.7
# 1882     82.9
# 1883       59
# 1884     93.5
# 1886     50.6
# 1887     74.9
# 1888     76.6
# 1889     65.7
# 1890     88.4
# 1892       29
# 1893     59.4
# 1894     98.2
# 1897     69.9
# 1898     34.2
# 1900     90.9
# 1902     77.9
# 1904      270
# 1908     16.7
# 1909     56.4
# 1912     69.9
# ...

# %%
c['每坪單價'] = c['每坪單價'].apply(lambda x: float(x)*10000)
c['每坪單價']
# Out:
# 0        758000.0
# 1        925000.0
# 2        913000.0
# 3             0.0
# 4        481000.0
# 5        856000.0
# 6        893000.0
# 7        731000.0
# 8        808000.0
# 9        855000.0
# 10       730000.0
# 11       614000.0
# 12       624000.0
# 13       808000.0
# 14       800000.0
# 15       546000.0
# 16       687000.0
# 18       820000.0
# 20       592000.0
# 21       607000.0
# 22       875000.0
# 23       867000.0
# 24       682000.0
# 25       589000.0
# 26       688000.0
# 27       907000.0
# 28       561000.0
# 29       950000.0
# 30       534000.0
# 31       501000.0
#           ...
# 1870     606000.0
# 1871     645000.0
# 1872    1013000.0
# 1873    1013000.0
# 1874     404000.0
# 1875    1168000.0
# 1876     432000.0
# 1877     816000.0
# 1878     371000.0
# 1879     698000.0
# 1880     737000.0
# 1882     829000.0
# 1883     590000.0
# 1884     935000.0
# 1886     506000.0
# 1887     749000.0
# 1888     766000.0
# 1889     657000.0
# 1890     884000.0
# ...

# %%
c.head()
# Out:
#         年月                  地址            類型                總價      每坪單價  \
# 0  107年03月         中正區仁愛路一段31號   電梯大樓/住宅 含車位   4388萬  (含車位--萬)  758000.0
# 1  107年03月         中正區寧波東街9巷1號         華廈/住宅             1150萬  925000.0
# 2  107年03月         中正區臨沂街29巷1號     華廈/住宅 含車位  3177萬  (含車位250萬)  913000.0
# 3  107年03月           中正區廈門街91號  電梯大樓/純車位 含車位   132萬  (含車位132萬)       0.0
# 4  107年03月  中正區新生南路一段140巷10弄1號   無電梯公寓/住宅/住宅              880萬  481000.0
#
#                    建坪     地坪     屋齡       樓層  \
# 0    57.88坪  (含車位--坪)  7.79坪  19.5年  2 /共16層
# 1              12.43坪  2.16坪  28.2年   4 /共7層
# 2  41.58坪  (含車位9.53坪)  9.34坪  25.2年   4 /共6層
# 3   4.75坪  (含車位4.75坪)  0.39坪   9.3年  1 /共12層
# 4               18.3坪  6.13坪  51.1年   2 /共4層
#
#                                     格局 特殊 housetype  car district
# 0     3房/2廳/2衛/0室 近捷運 善導寺站 》 近捷運 東門站 》  無      電梯大樓  含車位      中正區
# 1             1房/1廳/1衛/0室 近捷運 中正紀念堂站 》  無        華廈  無車位      中正區
# ...

# %%
c.columns
# Out:
# Index(['年月', '地址', '類型', '總價', '每坪單價', '建坪', '地坪', '屋齡', '樓層', '格局', '特殊',
#        'housetype', 'car', 'district'],
#       dtype='object')

# %%
c['cond'] = c['類型'].apply(lambda x: 'T' if '純車位' in x else 'F')
c
# Out:
#            年月                  地址               類型                  總價  \
# 0     107年03月         中正區仁愛路一段31號      電梯大樓/住宅 含車位     4388萬  (含車位--萬)
# 1     107年03月         中正區寧波東街9巷1號            華廈/住宅               1150萬
# 2     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位    3177萬  (含車位250萬)
# 3     107年03月           中正區廈門街91號     電梯大樓/純車位 含車位     132萬  (含車位132萬)
# 4     107年03月  中正區新生南路一段140巷10弄1號      無電梯公寓/住宅/住宅                880萬
# 5     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位    3758萬  (含車位250萬)
# 6     107年03月      中正區汀州路三段160巷1號            華廈/住宅                940萬
# 7     107年03月         中正區汀州路三段31號       電梯大樓/住宅/套房                980萬
# 8     107年03月       中正區新生南路一段151號  電梯大樓/辦公商業大樓 含車位    9250萬  (含車位600萬)
# 9     107年03月         中正區金山南路一段1號      電梯大樓/住宅 含車位    3880萬  (含車位400萬)
# 10    107年03月         中正區牯嶺街95巷1號          電梯大樓/住宅               2150萬
# 11    107年03月       中正區汀州路二段12巷1號            華廈/住宅               1100萬
# ...

# %%
c = c[c['cond'] == 'F']

# %%
c['類型'] = c['類型'].apply(lambda x: x if '純車位' in x else x)
c
# Out:
#            年月                  地址               類型       每坪單價  \
# 0     107年03月         中正區仁愛路一段31號      電梯大樓/住宅 含車位   758000.0
# 1     107年03月         中正區寧波東街9巷1號            華廈/住宅   925000.0
# 2     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位   913000.0
# 3     107年03月           中正區廈門街91號     電梯大樓/純車位 含車位        0.0
# 4     107年03月  中正區新生南路一段140巷10弄1號      無電梯公寓/住宅/住宅   481000.0
# 5     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位   856000.0
# 6     107年03月      中正區汀州路三段160巷1號            華廈/住宅   893000.0
# 7     107年03月         中正區汀州路三段31號       電梯大樓/住宅/套房   731000.0
# 8     107年03月       中正區新生南路一段151號  電梯大樓/辦公商業大樓 含車位   808000.0
# 9     107年03月         中正區金山南路一段1號      電梯大樓/住宅 含車位   855000.0
# 10    107年03月         中正區牯嶺街95巷1號          電梯大樓/住宅   730000.0
# 11    107年03月       中正區汀州路二段12巷1號            華廈/住宅   614000.0
# 12    107年03月        中正區和平西路二段31號         華廈/套房/住宅   624000.0
# 13    107年02月         中正區臨沂街19巷1號         無電梯公寓/住宅   808000.0
# ...

# %%
c.columns
# Out:
# Index(['年月', '地址', '類型', '每坪單價', '建坪', '地坪', '屋齡', '樓層', '格局', '特殊',
#        'housetype', 'car', 'district', 'cond'],
#       dtype='object')

# %%
c = c[['年月', '地址', '類型', '每坪單價', '建坪', '地坪', '屋齡', '樓層', '格局', '特殊',
       'housetype', 'car', 'district']]
c
# Out:
#            年月                  地址               類型       每坪單價  \
# 0     107年03月         中正區仁愛路一段31號      電梯大樓/住宅 含車位   758000.0
# 1     107年03月         中正區寧波東街9巷1號            華廈/住宅   925000.0
# 2     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位   913000.0
# 4     107年03月  中正區新生南路一段140巷10弄1號      無電梯公寓/住宅/住宅   481000.0
# 5     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位   856000.0
# 6     107年03月      中正區汀州路三段160巷1號            華廈/住宅   893000.0
# 7     107年03月         中正區汀州路三段31號       電梯大樓/住宅/套房   731000.0
# 8     107年03月       中正區新生南路一段151號  電梯大樓/辦公商業大樓 含車位   808000.0
# 9     107年03月         中正區金山南路一段1號      電梯大樓/住宅 含車位   855000.0
# 10    107年03月         中正區牯嶺街95巷1號          電梯大樓/住宅   730000.0
# 11    107年03月       中正區汀州路二段12巷1號            華廈/住宅   614000.0
# 12    107年03月        中正區和平西路二段31號         華廈/套房/住宅   624000.0
# 13    107年02月         中正區臨沂街19巷1號         無電梯公寓/住宅   808000.0
# 14    107年02月         中正區濟南路二段31號  無電梯公寓/住宅/辦公商業大樓   800000.0
# ...

# %%
c['建坪']=c['建坪'].apply(lambda x: x.split('坪')[0])
c['建坪']
# Out:
# 0        57.88
# 1        12.43
# 2        41.58
# 4         18.3
# 5         50.5
# 6        10.53
# 7         13.4
# 8       132.75
# 9        52.14
# 10       29.45
# 11       17.91
# 12       13.43
# 13       31.82
# 14       36.66
# 15       38.08
# 16        42.3
# 18       29.76
# 20       22.77
# 21       29.81
# 22       98.76
# 23       19.47
# 24       27.87
# 25       20.36
# 26       28.05
# 27       47.95
# 28       28.67
# 29       10.63
# 30       52.08
# 31       31.32
# 33       23.85
#          ...
# 1870    495.15
# 1871     21.61
# 1872       8.3
# 1873       8.3
# 1874     21.29
# 1875     89.92
# 1876      63.4
# 1877     36.77
# 1878      6.73
# 1879      9.53
# 1880     10.85
# 1882     15.69
# 1883     25.41
# 1884     59.11
# 1886     19.47
# 1887     54.56
# 1888     27.79
# 1889     67.91
# 1890     10.64
# 1892       3.8
# 1893     31.14
# 1894     29.02
# 1897    125.95
# 1898     18.08
# 1900     146.2
# 1902     28.22
# 1904       260
# ...

# %%
c.head()
# Out:
#         年月                  地址           類型      每坪單價     建坪      地坪     屋齡  \
# 0  107年03月         中正區仁愛路一段31號  電梯大樓/住宅 含車位  758000.0  57.88   7.79坪  19.5年
# 1  107年03月         中正區寧波東街9巷1號        華廈/住宅  925000.0  12.43   2.16坪  28.2年
# 2  107年03月         中正區臨沂街29巷1號    華廈/住宅 含車位  913000.0  41.58   9.34坪  25.2年
# 4  107年03月  中正區新生南路一段140巷10弄1號  無電梯公寓/住宅/住宅  481000.0   18.3   6.13坪  51.1年
# 5  107年03月         中正區臨沂街29巷1號    華廈/住宅 含車位  856000.0   50.5  11.73坪  25.2年
#
#         樓層                                   格局 特殊 housetype  car district
# 0  2 /共16層     3房/2廳/2衛/0室 近捷運 善導寺站 》 近捷運 東門站 》  無      電梯大樓  含車位      中正區
# 1   4 /共7層             1房/1廳/1衛/0室 近捷運 中正紀念堂站 》  無        華廈  無車位      中正區
# 2   4 /共6層    3房/2廳/2衛/1室 近捷運 忠孝新生站 》 社區 冠德龍邸 》  無        華廈  含車位      中正區
# 4   2 /共4層  4房/2廳/2衛/0室 近捷運 大安森林公園站 》 近捷運 東門站 》  無     無電梯公寓  無車位      中正區
# 5   5 /共6層    4房/2廳/2衛/0室 近捷運 忠孝新生站 》 社區 冠德龍邸 》  無        華廈  含車位      中正區

# %%
c['地坪']=c['地坪'].apply(lambda x:x.split('坪')[0])
c['地坪']
# Out:
# 0        7.79
# 1        2.16
# 2        9.34
# 4        6.13
# 5       11.73
# 6         2.3
# 7        2.15
# 8       20.86
# 9        5.75
# 10       6.52
# 11       5.19
# 12        3.2
# 13      10.51
# 14      13.23
# 15       6.62
# 16      19.59
# 18       7.75
# 20       5.14
# 21       3.55
# 22       6.47
# 23       2.45
# 24       3.42
# 25        3.9
# 26       8.59
# 27       6.16
# 28       5.45
# 29       1.18
# 30       5.22
# 31       7.16
# 33       7.11
#         ...
# 1870     57.9
# 1871     7.96
# 1872     3.58
# 1873     3.58
# 1874     6.05
# 1875    10.19
# 1876     5.22
# 1877    12.55
# 1878     1.29
# 1879     0.86
# 1880     1.12
# 1882     1.56
# 1883     9.03
# 1884     5.39
# 1886     6.88
# 1887    13.61
# 1888    10.44
# 1889    12.74
# 1890     1.69
# 1892      0.2
# 1893     3.56
# 1894    14.82
# 1897    16.29
# 1898     7.44
# 1900    14.25
# 1902     3.29
# 1904    44.72
# 1908     0.41
# 1909     3.55
# 1912    11.73
# ...

# %%
c.head(10)
# Out:
#          年月                  地址               類型      每坪單價      建坪     地坪  \
# 0   107年03月         中正區仁愛路一段31號      電梯大樓/住宅 含車位  758000.0   57.88   7.79
# 1   107年03月         中正區寧波東街9巷1號            華廈/住宅  925000.0   12.43   2.16
# 2   107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位  913000.0   41.58   9.34
# 4   107年03月  中正區新生南路一段140巷10弄1號      無電梯公寓/住宅/住宅  481000.0    18.3   6.13
# 5   107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位  856000.0    50.5  11.73
# 6   107年03月      中正區汀州路三段160巷1號            華廈/住宅  893000.0   10.53    2.3
# 7   107年03月         中正區汀州路三段31號       電梯大樓/住宅/套房  731000.0    13.4   2.15
# 8   107年03月       中正區新生南路一段151號  電梯大樓/辦公商業大樓 含車位  808000.0  132.75  20.86
# 9   107年03月         中正區金山南路一段1號      電梯大樓/住宅 含車位  855000.0   52.14   5.75
# 10  107年03月         中正區牯嶺街95巷1號          電梯大樓/住宅  730000.0   29.45   6.52
#
#        屋齡        樓層                                   格局 特殊 housetype  car  \
# 0   19.5年   2 /共16層     3房/2廳/2衛/0室 近捷運 善導寺站 》 近捷運 東門站 》  無      電梯大樓  含車位
# ...

# %%
c['floor']=c['樓層'].apply(lambda x:x.split('/')[0])

# %%
c['floorsum']=c['樓層'].apply(lambda x:x.split('/')[1])

# %%
c.head()
# Out:
#         年月                  地址           類型      每坪單價     建坪     地坪     屋齡  \
# 0  107年03月         中正區仁愛路一段31號  電梯大樓/住宅 含車位  758000.0  57.88   7.79  19.5年
# 1  107年03月         中正區寧波東街9巷1號        華廈/住宅  925000.0  12.43   2.16  28.2年
# 2  107年03月         中正區臨沂街29巷1號    華廈/住宅 含車位  913000.0  41.58   9.34  25.2年
# 4  107年03月  中正區新生南路一段140巷10弄1號  無電梯公寓/住宅/住宅  481000.0   18.3   6.13  51.1年
# 5  107年03月         中正區臨沂街29巷1號    華廈/住宅 含車位  856000.0   50.5  11.73  25.2年
#
#         樓層                                   格局 特殊 housetype  car district  \
# 0  2 /共16層     3房/2廳/2衛/0室 近捷運 善導寺站 》 近捷運 東門站 》  無      電梯大樓  含車位      中正區
# 1   4 /共7層             1房/1廳/1衛/0室 近捷運 中正紀念堂站 》  無        華廈  無車位      中正區
# 2   4 /共6層    3房/2廳/2衛/1室 近捷運 忠孝新生站 》 社區 冠德龍邸 》  無        華廈  含車位      中正區
# 4   2 /共4層  4房/2廳/2衛/0室 近捷運 大安森林公園站 》 近捷運 東門站 》  無     無電梯公寓  無車位      中正區
# 5   5 /共6層    4房/2廳/2衛/0室 近捷運 忠孝新生站 》 社區 冠德龍邸 》  無        華廈  含車位      中正區
#
#   floor floorsum
# 0    2      共16層
# 1    4       共7層
# ...

# %%
c['floorsum']=c['floorsum'].apply(lambda x:x.split('共')[1])

# %%
c['floorsum']=c['floorsum'].apply(lambda x:x.split('層')[0])
c
# Out:
#            年月                  地址               類型       每坪單價      建坪     地坪  \
# 0     107年03月         中正區仁愛路一段31號      電梯大樓/住宅 含車位   758000.0   57.88   7.79
# 1     107年03月         中正區寧波東街9巷1號            華廈/住宅   925000.0   12.43   2.16
# 2     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位   913000.0   41.58   9.34
# 4     107年03月  中正區新生南路一段140巷10弄1號      無電梯公寓/住宅/住宅   481000.0    18.3   6.13
# 5     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位   856000.0    50.5  11.73
# 6     107年03月      中正區汀州路三段160巷1號            華廈/住宅   893000.0   10.53    2.3
# 7     107年03月         中正區汀州路三段31號       電梯大樓/住宅/套房   731000.0    13.4   2.15
# 8     107年03月       中正區新生南路一段151號  電梯大樓/辦公商業大樓 含車位   808000.0  132.75  20.86
# 9     107年03月         中正區金山南路一段1號      電梯大樓/住宅 含車位   855000.0   52.14   5.75
# 10    107年03月         中正區牯嶺街95巷1號          電梯大樓/住宅   730000.0   29.45   6.52
# 11    107年03月       中正區汀州路二段12巷1號            華廈/住宅   614000.0   17.91   5.19
# ...

# %%
c['villa']=c['格局'].apply(lambda x:'有社區' if '社區' in x else '無社區')
c
# Out:
#            年月                  地址               類型       每坪單價      建坪     地坪  \
# 0     107年03月         中正區仁愛路一段31號      電梯大樓/住宅 含車位   758000.0   57.88   7.79
# 1     107年03月         中正區寧波東街9巷1號            華廈/住宅   925000.0   12.43   2.16
# 2     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位   913000.0   41.58   9.34
# 4     107年03月  中正區新生南路一段140巷10弄1號      無電梯公寓/住宅/住宅   481000.0    18.3   6.13
# 5     107年03月         中正區臨沂街29巷1號        華廈/住宅 含車位   856000.0    50.5  11.73
# 6     107年03月      中正區汀州路三段160巷1號            華廈/住宅   893000.0   10.53    2.3
# 7     107年03月         中正區汀州路三段31號       電梯大樓/住宅/套房   731000.0    13.4   2.15
# 8     107年03月       中正區新生南路一段151號  電梯大樓/辦公商業大樓 含車位   808000.0  132.75  20.86
# 9     107年03月         中正區金山南路一段1號      電梯大樓/住宅 含車位   855000.0   52.14   5.75
# 10    107年03月         中正區牯嶺街95巷1號          電梯大樓/住宅   730000.0   29.45   6.52
# 11    107年03月       中正區汀州路二段12巷1號            華廈/住宅   614000.0   17.91   5.19
# ...

# %%
c.columns
# Out:
# Index(['年月', '地址', '類型', '每坪單價', '建坪', '地坪', '屋齡', '樓層', '格局', '特殊',
#        'housetype', 'car', 'district', 'floor', 'floorsum', 'villa'],
#       dtype='object')

# %%
c = c[['年月', '地址','每坪單價', '建坪', '地坪', '屋齡', '格局', '特殊',
       'housetype', 'car', 'district', 'floor', 'floorsum', 'villa']]
c
# Out:
#            年月                  地址       每坪單價      建坪     地坪     屋齡  \
# 0     107年03月         中正區仁愛路一段31號   758000.0   57.88   7.79  19.5年
# 1     107年03月         中正區寧波東街9巷1號   925000.0   12.43   2.16  28.2年
# 2     107年03月         中正區臨沂街29巷1號   913000.0   41.58   9.34  25.2年
# 4     107年03月  中正區新生南路一段140巷10弄1號   481000.0    18.3   6.13  51.1年
# 5     107年03月         中正區臨沂街29巷1號   856000.0    50.5  11.73  25.2年
# 6     107年03月      中正區汀州路三段160巷1號   893000.0   10.53    2.3  11.2年
# 7     107年03月         中正區汀州路三段31號   731000.0    13.4   2.15  19.1年
# 8     107年03月       中正區新生南路一段151號   808000.0  132.75  20.86  27.3年
# 9     107年03月         中正區金山南路一段1號   855000.0   52.14   5.75   3.7年
# 10    107年03月         中正區牯嶺街95巷1號   730000.0   29.45   6.52  10.2年
# 11    107年03月       中正區汀州路二段12巷1號   614000.0   17.91   5.19     9年
# 12    107年03月        中正區和平西路二段31號   624000.0   13.43    3.2  21.6年
# 13    107年02月         中正區臨沂街19巷1號   808000.0   31.82  10.51    44年
# ...

# %%
c['屋齡']=c['屋齡'].apply(lambda x:x.split('年')[0])
c
# Out:
# C:\Users\Big data\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#            年月                  地址       每坪單價      建坪     地坪    屋齡  \
# 0     107年03月         中正區仁愛路一段31號   758000.0   57.88   7.79  19.5
# 1     107年03月         中正區寧波東街9巷1號   925000.0   12.43   2.16  28.2
# 2     107年03月         中正區臨沂街29巷1號   913000.0   41.58   9.34  25.2
# 4     107年03月  中正區新生南路一段140巷10弄1號   481000.0    18.3   6.13  51.1
# 5     107年03月         中正區臨沂街29巷1號   856000.0    50.5  11.73  25.2
# 6     107年03月      中正區汀州路三段160巷1號   893000.0   10.53    2.3  11.2
# 7     107年03月         中正區汀州路三段31號   731000.0    13.4   2.15  19.1
# ...

# %%
if
